# %% [markdown]
# # Solar system simulation treatment

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib

from matplotlib.patches import Ellipse, Polygon  # Used to draw shapes inside plots
from matplotlib.dates import MinuteLocator, DateFormatter, SecondLocator

# %%
import matplotlib.pyplot as plt
# %matplotlib qt

# %% [markdown]
# ## Fonctions

# %%
def convert_to_datetime(step, start=datetime.datetime(2014, 1, 1)):
    """
      This parser convert to a real datetime format
    """
    for el in step:
        yield start + datetime.timedelta(seconds=int(el))

# %%
def data_steps_iterator(dataframe, start=0, steps=[], interval=None):
    """
        Create an iterator to treat a dataframe by parts
        
        example :
            start=0
            steps=[el*48 for el in (31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31)]
            interval=12
        --> Month dataframe iterator
    """
    end = start + steps[0]
    yield dataframe[start:end]
    for el in range(interval-1):
        start = end
        end += steps[el+1]
        yield dataframe[start:end]

# %%
def set_boxes(box, colors=('#268bd2', '#002b36', '#268bd2', '#268bd2', '#dc322f'),
                   linewidth=(1.5, 1, 1, 0.5, 1), marker=''): 
    """
        Change boxplot color structure
        current display colors are : ('blue', 'black', 'blue', 'blue', 'red')
    """
    plt.setp(box['boxes'], color=colors[0], linewidth=linewidth[0])  # boxes 
    plt.setp(box['caps'], color=colors[1], linewidth=linewidth[1])  # limits 
    plt.setp(box['whiskers'], color=colors[2], linewidth=linewidth[2])  # points 
    plt.setp(box['fliers'], color=colors[3], linewidth=linewidth[3],
             marker=marker)  # markers
    plt.setp(box['medians'], color=colors[4], linewidth=linewidth[4])  # medians

# %%
# Not working !!!
def color_boxes(box_plot, numBoxes, facecolor):
    """
        Iterate (numBoxes iterations) over box_plot['boxes'] coordinates to draw
        a polygon which matched box plot boxes.
        Can be used to change boxes background color
    """
    for i in range(numBoxes):
        box = box_plot['boxes'][i]
        boxX = (box.get_xdata()[j] for j in range(5))
        boxY = (box.get_ydata()[j] for j in range(5))
        yield Polygon(zip(boxX, boxY), facecolor=facecolor)

# %% [markdown]
# ## Matplotlib parameters

# %%
# Change font properties
font_base = {'family' : 'serif',
             'size'   : 13}
font_title = {'size'   : 18,
              'family':'Anonymous Pro'}
font_mainTitle = {'color': '#002b36',
                  'weight': 'bold',
                  'size': '25',
                  'family': 'Anonymous Pro'}

# Change default label settings
matplotlib.rc('font', **font_base)
matplotlib.rc('xtick', labelsize=10) 
matplotlib.rc('ytick', labelsize=10)
matplotlib.rc('legend', fontsize=10)
matplotlib.rc('legend', labelspacing=0.2)

# font = matplotlib.font_manager.FontProperties(family='Tahoma', size=12)
# matplotlib.rc('annotate', fontproperties=font)

# Adding artist element
el = Ellipse((2, -1), 0.5, 0.5)

# Formatter
minutes = MinuteLocator(interval=4)
minutes_formatter = DateFormatter("%M:%S")

secondes = SecondLocator(interval=10)
secondes_formatter = DateFormatter("%M:%S")

matplotlib.use('Qt4Agg')
matplotlib.rcParams['backend.qt4']='PySide'

# %%
# Here select folder
# %cd "D:\GitHub\SolarSystem\Outputs\clean"
# Out:
# D:\GitHub\SolarSystem\Outputs\clean

# %%
# Your Dataframe structure
chambery = pd.read_csv('chambery_30062014.csv', skiprows=1, delimiter=";", index_col="Date")
# Convert to datetime index
chambery.index = [ind for ind in convert_to_datetime(chambery.index)]
# Removes duplicated values
chambery = chambery.groupby(chambery.index).last()
chambery_all = chambery
# Resample to keep only one value each 30min (reduce data treatment and increase speed)
chambery = chambery[:].resample('30min').interpolate()
# Resample to have one value per incrementation (here per month)
chambery_month = chambery[:].resample('1m')
type(chambery.index)
# Out:
# pandas.tseries.index.DatetimeIndex

# %%
# Csv columns names
for i, col in enumerate(chambery.columns):
    print("column {} \t\t{}".format(i, col))
# Out:
# column 0 		T1
# column 1 		T2
# column 2 		T3
# column 3 		T4
# column 4 		T5
# column 5 		T7
# column 6 		T8
# column 7 		T9_ext
# column 8 		T12_house
# column 9 		S6_state
# column 10 		S5_state
# column 11 		S4_state
# column 12 		S2_state
# column 13 		Flow_S6
# column 14 		Flow_S5
# column 15 		Flow_S4
# column 16 		Flow_S2
# column 17 		Vextra_state
# column 18 		Vsolar_state
# column 19 		CHAUFF_state
# column 20 		ECS_state
# column 21 		Backup_algo_state
# column 22 		Backup_state
# column 23 		Flow_Collector
# column 24 		Flow_ExchTank_bot
# column 25 		Flow_ExchTank_top
# column 26 		Flow_ExchStorTank
# column 27 		Flow_Boiler
# column 28 		HDifHor
# column 29 		HDirNor
# column 30 		HDifTil_collector
# column 31 		HDirTil_collector
# column 32 		Collector_Energy
# column 33 		Boiler_Energy
# column 34 		Radiator_Energy
# column 35 		DrawingUp_Energy

# %% [markdown]
# ## Box plot

# %%
# Month variation of temperatures
months = (31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31)
# Store dataframe values of each months inside a tuple 
T3_T4_T5 = tuple(el for el in data_steps_iterator(chambery[['T3', 'T4', 'T5']],
                                                 steps=[el*48 for el in months],
                                                 interval=12))
T1_Tint = [el for el in data_steps_iterator(chambery[['T1', 'T12_house']],
                                                 steps=[el*48 for el in months],
                                                 interval=12)]

Hdif_Hdir = [el for el in data_steps_iterator(chambery[['HDifHor', 'HDirNor']],
                                      steps=[el*48 for el in months],
                                      interval=12)]
# Keep only daily sun values (8h to 18h30)
for i in range(len(Hdif_Hdir)):
    Hdif_Hdir[i] = Hdif_Hdir[i].loc[Hdif_Hdir[i].index.hour <= 18]
    Hdif_Hdir[i] = Hdif_Hdir[i].loc[Hdif_Hdir[i].index.hour >= 9]
for i in range(len(T1_Tint)):
    T1_Tint[i] = T1_Tint[i].loc[T1_Tint[i].index.hour <= 18]
    T1_Tint[i] = T1_Tint[i].loc[T1_Tint[i].index.hour >= 9]
len(chambery_month), len(T3_T4_T5), len(T1_Text), len(Hdif_Hdir)  # Testing
# Out:
# (13, 12, 12, 12)

# %% [markdown]
# ### T3 T4 T5

# %%
# Prepare figure and adjust it
fig = plt.figure(figsize=(20, 10), facecolor=(0.84, 0.89, 0.9))
ax11 = fig.add_subplot(1, 1, 1)
fig.subplots_adjust(top=0.85,bottom=0.05,left=0.05,right=0.95)
fig.canvas.manager.set_window_title("")
text = "Evolution mensuel de la variation des températures des ballons"
plt.figtext(0.5, 0.9, text,
            ha='center', fontdict=font_mainTitle)

# Iterate to T3_T4 to get a specific column of values

# Draw T3 boxes
T3 = ax11.boxplot([el['T3'] for el in T3_T4_T5],
                  positions=[el for el in range(0, 12*4, 4)], widths = 0.6)
set_boxes(T3, colors=('#268bd2', '#002b36', '#268bd2', '#268bd2', '#dc322f'))

# Draw T4 boxes
T4 = ax11.boxplot([el['T4'] for el in T3_T4_T5],
                  positions=[el for el in range(1, 12*4, 4)], widths = 0.6)
set_boxes(T4, colors=('#586e75', '#002b36', '#586e75', '#586e75', '#dc322f'))
    
# Draw T5 boxes
T5 = ax11.boxplot([el['T5'] for el in T3_T4_T5],
                  positions=[el for el in range(2, 12*4, 4)], widths = 0.6)
set_boxes(T5, colors=('#859900', '#002b36', '#859900', '#859900', '#dc322f'))

# Change xticks values to put xtickslabels between boxes (same tick per boxes pair)
ax11.set_xticks([el for el in range(1, 12*4, 4)])
ax11.set_xlim((-1, 12*4))
ax11.set_xticklabels(['{:%B}'.format(el) for el in chambery_month.index])

# Draw temporary lines and use them to create a legend
h1, = ax11.plot([1,1], '#268bd2')
h2, = ax11.plot([1,1], '#586e75')
h3, = ax11.plot([1,1], '#859900')
ax11.legend((h1, h2, h3),('T3', 'T4', 'T5'), prop=font_title)
h1.set_visible(False)
h2.set_visible(False)
h3.set_visible(False)

fig.autofmt_xdate(0.1)

# %% [markdown]
# ### T1 Text

# %%
# Prepare figure and adjust it
fig = plt.figure(figsize=(20, 10), facecolor=(0.84, 0.89, 0.9))
ax11 = fig.add_subplot(1, 1, 1)
fig.subplots_adjust(top=0.85,bottom=0.05,left=0.05,right=0.95)
fig.canvas.manager.set_window_title("")
text = "Evolution mensuel de la variation des températures\n" + \
       " du collecteur (T1) et du ballon de stockage(T5)"
plt.figtext(0.5, 0.9, text,
            ha='center', fontdict=font_mainTitle)

# Iterate to T1_T5 to get a specific column of values

# Draw T1 boxes
T1 = ax11.boxplot([el['T1'] for el in T1_Tint],
                  positions=[el for el in range(0, 12*3, 3)], widths = 0.6)
set_boxes(T1, colors=('#268bd2', '#002b36', '#268bd2', '#268bd2', '#dc322f'))

# Draw T12 boxes
Tint = ax11.boxplot([el['T12_house'] for el in T1_Tint],
                  positions=[el for el in range(1, 12*3, 3)], widths = 0.6)
set_boxes(Tint, colors=('#586e75', '#002b36', '#586e75', '#586e75', '#dc322f'))

# Change xticks values to put xtickslabels between boxes (same tick per boxes pair)
ax11.set_xticks(np.linspace(.5, 33.5, 12))  # float range
ax11.set_xlim((-1, 12*3))
ax11.set_xticklabels(['{:%B}'.format(el) for el in chambery_month.index])

# Draw temporary lines and use them to create a legend
h1, = ax11.plot([1,1], '#268bd2')
h2, = ax11.plot([1,1], '#586e75')
ax11.legend((h1, h2),('T1', 'Tint'), prop=font_title)
h1.set_visible(False)
h2.set_visible(False)

fig.autofmt_xdate(0.1)

# %% [markdown]
# ### Rayonnement diffus et direct

# %%
# Prepare figure and adjust it
fig = plt.figure(figsize=(20, 10), facecolor=(0.84, 0.89, 0.9))
ax11 = fig.add_subplot(1, 1, 1)
fig.subplots_adjust(top=0.85,bottom=0.05,left=0.05,right=0.95)
fig.canvas.manager.set_window_title("")
text = "Evolution mensuel de la variation du rayonnement\n" + \
       " diffus (Hdif) et direct(Hdir)"
plt.figtext(0.5, 0.9, text,
            ha='center', fontdict=font_mainTitle)

# Iterate to Hdif_Hdir to get a specific column of values during sun range
# Début 8h  Fin 18h

# Draw hdif boxes
hdif = ax11.boxplot([el['HDifHor'] for el in Hdif_Hdir],
                  positions=[el for el in range(0, 12*3, 3)], widths = 0.6)
set_boxes(hdif, colors=('#268bd2', '#002b36', '#268bd2', '#268bd2', '#dc322f'), marker='1')

# Draw hdir boxes
hdir = ax11.boxplot([el['HDirNor'] for el in Hdif_Hdir],
                  positions=[el for el in range(1, 12*3, 3)], widths = 0.6)
set_boxes(hdir, colors=('#586e75', '#002b36', '#586e75', '#586e75', '#dc322f'), marker='1')

# Change xticks values to put xtickslabels between boxes (same tick per boxes pair)
ax11.set_xticks(np.linspace(.5, 33.5, 12))  # float range
ax11.set_xlim((-1, 12*3))
ax11.set_ylim((-10, 1000))
ax11.set_xticklabels(['{:%B}'.format(el) for el in chambery_month.index])

# Draw temporary lines and use them to create a legend
h1, = ax11.plot([1,1], '#268bd2')
h2, = ax11.plot([1,1], '#586e75')
ax11.legend((h1, h2),('Hdif', 'Hdir'), prop=font_title)
h1.set_visible(False)
h2.set_visible(False)

fig.autofmt_xdate(0.1)

# %% [markdown]
# ## Pie chart

# %%
energy_final = chambery.ix[:, "Collector_Energy":"DrawingUp_Energy"]
energy_final["Taux de couverture"] = (energy_final["Collector_Energy"] /
                                    (energy_final["DrawingUp_Energy"] +
                                     energy_final["Radiator_Energy"]))
energy_final["Apports"] = (energy_final["Collector_Energy"] + 
                                 energy_final["Boiler_Energy"])
energy_final["Besoins"] = (energy_final["DrawingUp_Energy"] + 
                                 energy_final["Radiator_Energy"])
energy_final["Pertes"] = energy_final["Apports"]- energy_final["Besoins"]
energy_final[-1:]
# Out:
#                      Collector_Energy  Boiler_Energy  Radiator_Energy  \
# 2015-01-03 08:00:00           3807.08   10807.850769      9844.396154
#
#                      DrawingUp_Energy  Taux de couverture       Apports  \
# 2015-01-03 08:00:00       2053.013846            0.319992  14614.930769
#
#                       Besoins       Pertes
# 2015-01-03 08:00:00  11897.41  2717.520769
#
# [1 rows x 8 columns]

# %%
# Pie charts values must be inside the same datframe column
charts = (energy_final[['Pertes', 'Radiator_Energy', 'DrawingUp_Energy']][-1:]).T
charts
# Out:
#                   2015-01-03 08:00:00
# Pertes                    2717.520769
# Radiator_Energy           9844.396154
# DrawingUp_Energy          2053.013846
#
# [3 rows x 1 columns]

# %%
solar_frac = pd.DataFrame(energy_final[["Collector_Energy", 'Boiler_Energy']][-1:]).T
solar_frac
# Out:
#                   2015-01-03 08:00:00
# Collector_Energy          3807.080000
# Boiler_Energy            10807.850769
#
# [2 rows x 1 columns]

# %% [markdown]
# ### Collector, boiler and heating, drawing up, losses

# %%
explode1 = (0.1, 0)  # only "explode" the 1st slice (i.e. 'Collector_Energy')
explode2 = (0, 0, 0)
# Colors    green      blue      orange      black     magenta
colors = ['#859900', '#268bd2', '#cb4b16', '#073642', '#d33682']
colors1 = ['#859900', '#268bd2', '#cb4b16']  
colors2 = ['#859900', '#268bd2']
labels = ['Solaire', 'Chaudière', 'Pertes', 'Chauffage', 'ECS']

# Prepare figure and adjust it
fig = plt.figure(figsize=(20, 10), facecolor=(0.84, 0.89, 0.9))
fig.subplots_adjust(top=0.85,bottom=0.05,left=0.05,right=0.95)
fig.canvas.manager.set_window_title("")
text = "Taux de couverture solaire de " + \
       "{:.2%}".format(energy_final['Taux de couverture'][-1:].values[0])
plt.figtext(0.5, 0.9, text,
            ha='center', fontdict=font_mainTitle)

ax11 = fig.add_subplot(1, 2, 1)
ax21 = fig.add_subplot(1, 2, 2)
fig.subplots_adjust(top=0.8,bottom=0.05,left=0.05, right=0.95, wspace=0.2)

# Change title parameters
ax11.set_title(label="Consommations",
               fontdict=font_title)
ax21.set_title(label="Répartition des consommations",
               fontdict=font_title)

ax11.pie(solar_frac,
         explode=explode1, colors=colors2,
         labels=labels[:2],
         autopct='%1.1f%%', shadow=True, startangle=90)
ax21.pie(charts,
         explode=explode2, colors=colors1,
         labels=labels[2:],
         autopct='%1.1f%%', shadow=True, startangle=90)

ax11.legend(prop=font_title)
ax21.legend(prop=font_title)

# Set aspect ratio to be equal so that pie is drawn as a circle.
# plt.axis('equal')

# %% [markdown]
# ## Line plot

# %% [markdown]
# ### Energy

# %%
# Prepare figure and adjust it
fig = plt.figure(figsize=(20, 10), facecolor=(0.84, 0.89, 0.9))
fig.canvas.manager.set_window_title("")
text = "Evolution des énergie du système solaire combiné"
plt.figtext(0.5, 0.9, text,
            ha='center', fontdict=font_mainTitle)
ax11 = fig.add_subplot(1, 1, 1)

chambery.ix[:, 'Collector_Energy':'DrawingUp_Energy'].plot(ax=ax11, colormap="Accent",
                                  linewidth=2)
ax11.legend(prop=font_title)

# Adding y axes labels with colors
ax11.set_ylabel('Kwh')

fig.autofmt_xdate()
fig.subplots_adjust(top=0.85,bottom=0.05,left=0.05, right=0.95, wspace=0.2)

# %% [markdown]
# ### Text Tinside

# %%
# Prepare figure and adjust it
fig = plt.figure(figsize=(20, 10), facecolor=(0.84, 0.89, 0.9))
fig.canvas.manager.set_window_title("")
text = "Evolution des énergie du système solaire combiné"
plt.figtext(0.5, 0.9, text,
            ha='center', fontdict=font_mainTitle)
ax11 = fig.add_subplot(1, 1, 1)
fig.subplots_adjust(top=0.8,bottom=0.05,left=0.05, right=0.95, wspace=0.2)

chambery[['T9_ext', 'T12_house']].plot(ax=ax11, colormap="Accent",
                                      linewidth=2)
ax11.legend(prop=font_title)

# Adding y axes labels with colors
ax11.set_ylabel('°C')

fig.autofmt_xdate()

# %% [markdown]
# ### T1 T3 T4 T5, Vextra, Vsolar

# %%
# Prepare figure and adjust it
fig = plt.figure(figsize=(20, 10), facecolor=(0.84, 0.89, 0.9))
fig.canvas.manager.set_window_title("")
text = "Evolution des température T1, T3, T4, T5"
plt.figtext(0.5, 0.9, text,
            ha='center', fontdict=font_mainTitle)
ax11 = fig.add_subplot(2, 1, 1)
ax12 = fig.add_subplot(2, 1, 2, sharex=ax11)

chambery_all[['T1', 'T3', 'T4', 'T5']].plot(ax=ax11, colormap="Accent",
                                                  linewidth=1, ylim=(-1, 130))
ax11.legend(prop=font_title)
chambery_all[['Vextra_state', 'Vsolar_state']].plot(ax=ax12, color=('#cb4b16', '#859900'),
                                                          linewidth=2, ylim=(-1, 130))
ax12.legend(prop=font_title)

# Adding y axes labels with colors
ax11.set_ylabel('°C')

fig.autofmt_xdate()
fig.subplots_adjust(top=0.85,bottom=0.05,left=0.05, right=0.95)

# %% [markdown]
# ## Testing

# %%
# Group data per month and check index values
for el in data_iterator(struct=chambery.index,
                             steps=[el*48 for el in (31, 28, 31, 30, 31, 30, 31, 31, 30, 31, 30, 31)],
                             interval=12):
    print(len(el), "\t", "month day :", len(el)//(24*2), "\t", el[0], "\t", el[-1])
print("\nLast index value are : ", chambery.index[-1])
# Out:
# 1488 	 month day : 31 	 2014-01-01 00:00:00 	 2014-01-31 23:30:00
# 1344 	 month day : 28 	 2014-02-01 00:00:00 	 2014-02-28 23:30:00
# 1488 	 month day : 31 	 2014-03-01 00:00:00 	 2014-03-31 23:30:00
# 1440 	 month day : 30 	 2014-04-01 00:00:00 	 2014-04-30 23:30:00
# 1488 	 month day : 31 	 2014-05-01 00:00:00 	 2014-05-31 23:30:00
# 1440 	 month day : 30 	 2014-06-01 00:00:00 	 2014-06-30 23:30:00
# 1488 	 month day : 31 	 2014-07-01 00:00:00 	 2014-07-31 23:30:00
# 1488 	 month day : 31 	 2014-08-01 00:00:00 	 2014-08-31 23:30:00
# 1440 	 month day : 30 	 2014-09-01 00:00:00 	 2014-09-30 23:30:00
# 1488 	 month day : 31 	 2014-10-01 00:00:00 	 2014-10-31 23:30:00
# 1440 	 month day : 30 	 2014-11-01 00:00:00 	 2014-11-30 23:30:00
# 17 	 month day : 0 	 2014-12-01 00:00:00 	 2014-12-01 08:00:00
#
# Last index value are :  2014-12-01 08:00:00

# %%
# Testing float range
np.linspace(1.5, 34.5, 12)
# Out:
# array([  1.5,   4.5,   7.5,  10.5,  13.5,  16.5,  19.5,  22.5,  25.5,
#         28.5,  31.5,  34.5])

# %%
# Get all colormaps
maps=[m for m in matplotlib.colorbar.cm.datad if not m.endswith("_r")]
maps.sort()
for i, m in enumerate(maps):
    print(i, m)
# Out:
# 0 Accent
# 1 Blues
# 2 BrBG
# 3 BuGn
# 4 BuPu
# 5 CMRmap
# 6 Dark2
# 7 GnBu
# 8 Greens
# 9 Greys
# 10 OrRd
# 11 Oranges
# 12 PRGn
# 13 Paired
# 14 Pastel1
# 15 Pastel2
# 16 PiYG
# 17 PuBu
# 18 PuBuGn
# 19 PuOr
# 20 PuRd
# 21 Purples
# 22 RdBu
# 23 RdGy
# 24 RdPu
# 25 RdYlBu
# 26 RdYlGn
# 27 Reds
# 28 Set1
# 29 Set2
# 30 Set3
# 31 Spectral
# 32 YlGn
# 33 YlGnBu
# 34 YlOrBr
# 35 YlOrRd
# 36 afmhot
# 37 autumn
# 38 binary
# 39 bone
# 40 brg
# 41 bwr
# 42 cool
# 43 coolwarm
# 44 copper
# 45 cubehelix
# 46 flag
# 47 gist_earth
# 48 gist_gray
# 49 gist_heat
# 50 gist_ncar
# 51 gist_rainbow
# 52 gist_stern
# 53 gist_yarg
# 54 gnuplot
# 55 gnuplot2
# 56 gray
# 57 hot
# 58 hsv
# 59 jet
# 60 nipy_spectral
# 61 ocean
# 62 pink
# 63 prism
# 64 rainbow
# 65 seismic
# 66 spectral
# 67 spring
# 68 summer
# 69 terrain
# 70 winter

# %%
test = data_range_iterator((el for el in data_steps_iterator(chambery[['T3', 'T4', 'T5']],
                                                             steps=[el*48 for el in months],
                                                             interval=12)), columns='T3')
for el in test:
    print(el)
# Out:
# 2014-01-01 08:00:00    19.790312
# 2014-01-01 08:30:00    19.821698
# 2014-01-01 09:00:00    19.839615
# 2014-01-01 09:30:00    19.871250
# 2014-01-01 10:00:00    19.900400
# 2014-01-01 10:30:00    19.936129
# 2014-01-01 11:00:00    19.968800
# 2014-01-01 11:30:00    20.017458
# 2014-01-01 12:00:00    19.974444
# 2014-01-01 12:30:00    19.905385
# 2014-01-01 13:00:00    19.867500
# 2014-01-01 13:30:00    19.891400
# 2014-01-01 14:00:00    19.164516
# 2014-01-01 14:30:00    18.781471
# 2014-01-01 15:00:00    20.922353
# 2014-01-01 15:30:00    21.938485
# 2014-01-01 16:00:00    22.063158
# 2014-01-01 16:30:00    22.080000
# 2014-01-01 17:00:00    22.073043
# 2014-01-01 17:30:00    22.070000
# 2014-01-01 18:00:00    22.070000
# Freq: 30T, Name: T3, dtype: float64
# 2014-01-02 08:00:00    19.245152
# 2014-01-02 08:30:00    19.221273
# 2014-01-02 09:00:00    19.218000
# 2014-01-02 09:30:00    19.210000
# 2014-01-02 10:00:00    19.210000
# 2014-01-02 10:30:00    19.159444
# 2014-01-02 11:00:00    22.677241
# 2014-01-02 11:30:00    28.687167
# 2014-01-02 12:00:00    30.721000
# 2014-01-02 12:30:00    30.308929
# 2014-01-02 13:00:00    29.589143
# 2014-01-02 13:30:00    29.350364
# 2014-01-02 14:00:00    28.857187
# 2014-01-02 14:30:00    28.966889
# 2014-01-02 15:00:00    29.156000
# 2014-01-02 15:30:00    29.010588
# 2014-01-02 16:00:00    28.589412
# 2014-01-02 16:30:00    27.987368
# 2014-01-02 17:00:00    28.015000
# 2014-01-02 17:30:00    28.020000
# 2014-01-02 18:00:00    28.020000
# Freq: 30T, Name: T3, dtype: float64
# 2014-01-03 08:00:00    24.367297
# 2014-01-30 14:00:00    11.879091
# 2014-01-30 14:30:00    11.912143
# 2014-01-30 15:00:00    11.949091
# 2014-01-30 15:30:00    11.984231
# 2014-01-30 16:00:00    12.028750
# 2014-01-30 16:30:00    12.065455
# 2014-01-30 17:00:00    12.116923
# 2014-01-30 17:30:00    12.160000
# 2014-01-30 18:00:00    12.216207
# Freq: 30T, Name: T3, dtype: float64
# 2014-01-31 08:00:00    10.208400
# 2014-01-31 08:30:00    10.258387
# 2014-01-31 09:00:00    10.304138
# 2014-01-31 09:30:00    10.359615
# 2014-01-31 10:00:00    10.410690
# 2014-01-31 10:30:00    10.467857
# 2014-01-31 11:00:00    10.532759
# 2014-01-31 11:30:00    10.595417
# 2014-01-31 12:00:00    10.514667
# 2014-01-31 12:30:00    10.284000
# 2014-01-31 13:00:00    10.181379
# 2014-01-31 13:30:00    10.230690
# 2014-01-31 14:00:00    10.266667
# 2014-01-31 14:30:00    10.320333
# 2014-01-31 15:00:00    10.374000
# 2014-01-31 15:30:00    10.420400
# 2014-01-31 16:00:00    10.477500
# 2014-01-31 16:30:00    10.527500
# 2014-01-31 17:00:00    10.588462
# 2014-01-31 17:30:00    10.645556
# 2014-01-31 18:00:00    10.704231
# Freq: 30T, Name: T3, dtype: float64
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# ...
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)
# Series([], name: T3, dtype: float64)

# %%
from itertools import chain, islice

# Iteration per parts (multiple steps)
def morceaux_steps(iterable, steps=[], format=iter):
    it = iter(iterable)
    i = 0
    while True:
        yield format(chain((next(it),), islice(it, steps[i] - 1)))
        i += 1

# Iteration per parts (same step)
def morceaux(iterable, step, format=iter):
    it = iter(iterable)
    while True:
        yield format(chain((next(it),), islice(it, step - 1)))

# Test
a = morceaux_steps((1, 2, 3, 4, 5, 6, 7), steps=(1, 2, 3, 54), format=tuple)
for el in a:
    print(el)
print("Pas d'erreur même si on demande une longueur plus grande que disponible")
print("Cependant il faut connaître la taille finale ou bien combler par un grand pas^^")
print("-------------------------------")
b = morceaux((1, 2, 3, 4, 5, 6, 7), step=2, format=tuple)
for el in b:
    print(el)
# Out:
# (1,)
# (2, 3)
# (4, 5, 6)
# (7,)
# Pas d'erreur même si on demande une longueur plus grande que disponible
# Cependant il faut connaître la taille finale ou bien combler par un grand pas^^
# -------------------------------
# (1, 2)
# (3, 4)
# (5, 6)
# (7,)

# %%
def datass_range_iterator(struct, columns, step=48, start=0):
    """
        Create an iterator to treat a list of dataframe and reduce
        each dataframe range according to start and step parameters
        step = steps inside one day
    """
    for datas in struct:  # 12 fois
        end = step     # Step and first end point
        deb = start    # Start point
        uu = list()
        for _ in range(len(datas)//step):
            uu.append(datas[columns][deb+16:end-11])
            deb, end = end, end+(end-deb)
        yield uu

# %%
test = datass_range_iterator(struct=(el for el in data_steps_iterator(chambery[['T3', 'T4', 'T5']],
                                                 steps=[el*48 for el in months],
                                                 interval=12)),
                            columns="T4")
oo = [el for el in test]
a = pd.DataFrame(oo[0][0].values, columns=("T",), index=oo[0][0].index)
a
# Out:
