# %% [markdown]
# # Dymola csv output post treatment

# %% [markdown]
# ## --- Prepare tools ---

# %% [markdown]
# #### Import useful library

# %%
import pandas as pd
import matplotlib.pyplot as plt
#import prettyplotlib as ppl
# %matplotlib qt
# To plot inline add 
# %matplotlib inline

# %%
import re        # Regex
import datetime  # Datetime parser

# %% [markdown]
# #### Change directory to working directory

# %%
cd C:\Users\bois\Documents\Python\Scripts
# Out:
# C:\Users\bois\Documents\Python\Scripts

# %% [markdown]
# #### Prepare datetime formatter

# %%
# Start time for timestep
year, month, day = 2014, 1, 1
start = datetime.datetime(year, month, day)
start
# Out:
# datetime.datetime(2014, 1, 1, 0, 0)

# %%
# This parser convert to a real datetime format
def convert_to_datetime(step):
    for el in step:
        yield start + datetime.timedelta(seconds=int(el))

# %%
# This parser convert into a solisart software format      
def convert_to_datetimestring(step):
    for el in step:
        yield datetime.datetime.strftime(start + datetime.timedelta(seconds=int(el+0.5)), "%d/%m/%Y %H:%M")

# %% [markdown]
# ## --- Prepare dymola output datas ---

# %% [markdown]
# #### Read file datas

# %%
test_plot = pd.read_csv("bad.csv", skiprows=1, delimiter=",", names=("Date", "T1", "T3", "T5"), index_col="Date")
test_solis = pd.read_csv("bad2.csv", skiprows=1, delimiter=",", names=("Time", "T1", "T3", "T5"), index_col="Time")

# %% [markdown]
# #### Remove duplicates

# %%
# Delete all duplicate time step
before = (len(test_plot.index), len(test_solis.index))
test_plot = test_plot.groupby(test_plot.index).last()
test_solis = test_solis.groupby(test_solis.index).last()
after = (len(test_plot.index), len(test_solis.index))
print("before:", before, "\t after:", after)
# Out:
# before: (63089, 63089) 	 after: (23389, 23389)

# %% [markdown]
# #### Convert columns values according to their fields.

# %%
# Cast kelvins to celsius
# Regular expression to catch column fields and do some modifications on them
reg = (re.compile("\AT\d+"), re.compile("\AHDi[fr]+"))
for column in test_plot.columns:
    if reg[0].match(column):
        test_plot[column] -= 273.15
    elif reg[1].match(column):
        test_plot[column] = 0
for column in test_solis.columns:
    if reg[0].match(column):
        test_solis[column] -= 273.15
    elif reg[1].match(column):
        test_solis[column] = 0

# %% [markdown]
# #### Parse timesteps and cast them as an index

# %%
# Parse time step to date
# Windows sucks again ... Can't change index with list comprehension ... (Works under Linux)
test_plot.index  = [ind for ind in convert_to_datetime(test_plot.index)]
test_solis.index  = [ind for ind in convert_to_datetimestring(test_solis.index)]
test_plot
# Out:
#                          T1      T3      T5
# 2014-01-01 00:00:00  50.000  15.000  20.000
# 2014-01-01 00:00:01  49.996  15.000  20.000
# 2014-01-01 00:01:40  49.598  15.009  19.998
# 2014-01-01 00:02:00  49.518  15.013  19.998
# 2014-01-01 00:03:20  49.200  15.059  19.997
# 2014-01-01 00:04:00  49.042  15.109  19.996
# 2014-01-01 00:05:00  48.805  15.192  19.995
# 2014-01-01 00:06:00  48.412  15.273  19.994
# 2014-01-01 00:06:40  47.183  15.324  19.993
# 2014-01-01 00:08:00  36.935  15.419  19.995
# 2014-01-01 00:08:20  33.176  15.439  19.997
# 2014-01-01 00:10:00  20.877  15.509  20.016
# 2014-01-01 00:11:40  19.249  15.528  20.022
# 2014-01-01 00:12:00  19.186  15.524  20.023
# 2014-01-01 00:13:20  19.097  15.502  20.029
# 2014-01-01 00:14:00  19.054  15.493  20.031
# 2014-01-01 00:15:00  18.990  15.483  20.035
# 2014-01-01 00:16:00  18.926  15.475  20.039
# 2014-01-01 00:16:40  18.884  15.471  20.041
# 2014-01-01 00:18:00  18.801  15.463  20.046
# 2014-01-01 00:18:20  18.780  15.461  20.047
# 2014-01-01 00:20:00  18.678  15.454  20.053
# 2014-01-01 00:21:40  18.578  15.448  20.058
# 2014-01-01 00:22:00  18.558  15.447  20.059
# 2014-01-01 00:23:20  18.479  15.443  20.063
# 2014-01-01 00:24:00  18.439  15.441  20.064
# 2014-01-01 00:25:00  18.381  15.439  20.067
# 2014-01-01 00:26:00  18.323  15.437  20.069
# 2014-01-01 00:26:40  18.285  15.435  20.071
# 2014-01-01 00:28:00  18.210  15.433  20.074
# 2014-01-01 00:28:20  18.191  15.432  20.075
# 2014-01-01 00:30:00  18.098  15.429  20.078
# 2014-01-01 00:31:40  18.007  15.426  20.081
# 2014-01-01 00:32:00  17.988  15.426  20.082
# 2014-01-01 00:33:20  17.916  15.424  20.084
# 2014-01-01 00:34:00  17.881  15.423  20.085
# 2014-01-01 00:35:00  17.828  15.422  20.087
# 2014-01-01 00:36:00  17.775  15.421  20.088
# 2014-01-01 00:36:40  17.740  15.420  20.089
# 2014-01-01 00:38:00  17.672  15.418  20.091
# 2014-01-01 00:38:20  17.654  15.418  20.091
# 2014-01-01 00:40:00  17.570  15.416  20.093
# 2014-01-01 00:41:40  17.486  15.414  20.094
# 2014-01-01 00:42:00  17.470  15.414  20.095
# 2014-01-01 00:43:20  17.404  15.413  20.096
# 2014-01-01 00:44:00  17.371  15.412  20.096
# 2014-01-01 00:45:00  17.323  15.411  20.097
# 2014-01-01 00:46:00  17.275  15.411  20.098
# 2014-01-01 00:46:40  17.243  15.410  20.098
# 2014-01-01 00:48:00  17.180  15.409  20.099
# 2014-01-01 00:48:20  17.164  15.409  20.099
# 2014-01-01 00:50:00  17.087  15.407  20.100
# 2014-01-01 00:51:40  17.010  15.406  20.101
# 2014-01-01 00:52:00  16.995  15.406  20.101
# 2014-01-01 00:53:20  16.935  15.405  20.101
# 2014-01-01 00:54:00  16.905  15.404  20.101
# 2014-01-01 00:55:00  16.861  15.404  20.102
# 2014-01-01 00:56:00  16.817  15.403  20.102
# 2014-01-01 00:56:40  16.787  15.402  20.102
# 2014-01-01 00:58:00  16.730  15.401  20.102
#                         ...     ...     ...
#
# [23389 rows x 3 columns]

# %%
test_solis
# Out:
#                       T1      T3      T5
# 01/01/2014 00:00  50.000  15.000  20.000
# 01/01/2014 00:00  49.996  15.000  20.000
# 01/01/2014 00:01  49.598  15.009  19.998
# 01/01/2014 00:02  49.518  15.013  19.998
# 01/01/2014 00:03  49.200  15.059  19.997
# 01/01/2014 00:04  49.042  15.109  19.996
# 01/01/2014 00:05  48.805  15.192  19.995
# 01/01/2014 00:06  48.412  15.273  19.994
# 01/01/2014 00:06  47.183  15.324  19.993
# 01/01/2014 00:08  36.935  15.419  19.995
# 01/01/2014 00:08  33.176  15.439  19.997
# 01/01/2014 00:10  20.877  15.509  20.016
# 01/01/2014 00:11  19.249  15.528  20.022
# 01/01/2014 00:12  19.186  15.524  20.023
# 01/01/2014 00:13  19.097  15.502  20.029
# 01/01/2014 00:14  19.054  15.493  20.031
# 01/01/2014 00:15  18.990  15.483  20.035
# 01/01/2014 00:16  18.926  15.475  20.039
# 01/01/2014 00:16  18.884  15.471  20.041
# 01/01/2014 00:18  18.801  15.463  20.046
# 01/01/2014 00:18  18.780  15.461  20.047
# 01/01/2014 00:20  18.678  15.454  20.053
# 01/01/2014 00:21  18.578  15.448  20.058
# 01/01/2014 00:22  18.558  15.447  20.059
# 01/01/2014 00:23  18.479  15.443  20.063
# 01/01/2014 00:24  18.439  15.441  20.064
# 01/01/2014 00:25  18.381  15.439  20.067
# 01/01/2014 00:26  18.323  15.437  20.069
# 01/01/2014 00:26  18.285  15.435  20.071
# 01/01/2014 00:28  18.210  15.433  20.074
# 01/01/2014 00:28  18.191  15.432  20.075
# 01/01/2014 00:30  18.098  15.429  20.078
# 01/01/2014 00:31  18.007  15.426  20.081
# 01/01/2014 00:32  17.988  15.426  20.082
# 01/01/2014 00:33  17.916  15.424  20.084
# 01/01/2014 00:34  17.881  15.423  20.085
# 01/01/2014 00:35  17.828  15.422  20.087
# 01/01/2014 00:36  17.775  15.421  20.088
# 01/01/2014 00:36  17.740  15.420  20.089
# 01/01/2014 00:38  17.672  15.418  20.091
# 01/01/2014 00:38  17.654  15.418  20.091
# 01/01/2014 00:40  17.570  15.416  20.093
# 01/01/2014 00:41  17.486  15.414  20.094
# 01/01/2014 00:42  17.470  15.414  20.095
# 01/01/2014 00:43  17.404  15.413  20.096
# 01/01/2014 00:44  17.371  15.412  20.096
# 01/01/2014 00:45  17.323  15.411  20.097
# 01/01/2014 00:46  17.275  15.411  20.098
# 01/01/2014 00:46  17.243  15.410  20.098
# 01/01/2014 00:48  17.180  15.409  20.099
# 01/01/2014 00:48  17.164  15.409  20.099
# 01/01/2014 00:50  17.087  15.407  20.100
# 01/01/2014 00:51  17.010  15.406  20.101
# 01/01/2014 00:52  16.995  15.406  20.101
# 01/01/2014 00:53  16.935  15.405  20.101
# 01/01/2014 00:54  16.905  15.404  20.101
# 01/01/2014 00:55  16.861  15.404  20.102
# 01/01/2014 00:56  16.817  15.403  20.102
# 01/01/2014 00:56  16.787  15.402  20.102
# 01/01/2014 00:58  16.730  15.401  20.102
#                      ...     ...     ...
#
# [23389 rows x 3 columns]

# %% [markdown]
# #### Show data after traitement with adapting scale

# %%
for field in test_plot.columns:
    
    # Create each plot with pretty print color and graph frames ...
    ppl.plot(test_plot.index, test_plot[field], linewidth=0.75, label=field)
    
    # 2 ways for change x axe ticks rotation
    #plt.setp(ax.get_xticklabels(), rotation=30)
    plt.xticks(rotation=30)
    plt.title("It's working dude")

# Display modification on the graph
ppl.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-e48b359941fd> in <module>()
#       2
#       3     # Create each plot with pretty print color and graph frames ...
# ----> 4     ppl.plot(test_plot.index, test_plot[field], linewidth=0.75, label=field)
#       5
#       6     # 2 ways for change x axe ticks rotation
#
# NameError: name 'ppl' is not defined

# %%
matplot_plot = test_plot.plot(title="It's working dude")

# %% [markdown]
# #### Other filtering treatments

# %%
# Filter by columns
test_plot[["T1","T3"]]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 23389 entries, 2014-01-01 00:00:00 to 2014-01-14 11:59:40
# Data columns (total 2 columns):
# T1    23389  non-null values
# T3    23389  non-null values
# dtypes: float64(2)

# %%
# Filter by columns and condition
test_plot[test_plot["T5"] <= 16.77]
# Out:
#                          T1      T3      T5
# 2014-01-06 11:00:00  17.089  10.928  16.768
# 2014-01-06 11:01:40  18.070  10.961  16.767
# 2014-01-06 11:02:00  18.364  10.966  16.767
# 2014-01-06 11:03:20  19.637  10.988  16.767
# 2014-01-06 11:04:00  20.268  11.000  16.766
# 2014-01-06 11:05:00  21.150  11.019  16.766
# 2014-01-06 11:06:00  21.942  11.041  16.765
# 2014-01-06 11:06:40  22.422  11.057  16.765
# 2014-01-06 11:08:00  23.282  11.092  16.765
# 2014-01-06 11:08:20  23.478  11.101  16.764
# 2014-01-06 11:10:00  23.894  11.153  16.765
# 2014-01-06 11:11:40  23.150  11.209  16.768
# 2014-01-06 11:12:00  22.821  11.220  16.769

# %%
# Filter by rows and columns (slicing works)
test_plot.ix["2014-01-01 00:00:00":"2014-01-01 00:03:20", ["T1", "T5", "T3"]]
# Out:
#                          T1      T5      T3
# 2014-01-01 00:00:00  50.000  20.000  15.000
# 2014-01-01 00:00:01  49.996  20.000  15.000
# 2014-01-01 00:01:40  49.598  19.998  15.009
# 2014-01-01 00:02:00  49.518  19.998  15.013
# 2014-01-01 00:03:20  49.200  19.997  15.059

# %%
# Filter by columns with condition (this two lines return the same array)
test_plot.ix[test_plot.T1 > 49, :"T3"]
test_plot.ix[test_plot.T1 > 49, :2]
# Out:
#                          T1      T3
# 2014-01-01 00:00:00  50.000  15.000
# 2014-01-01 00:00:01  49.996  15.000
# 2014-01-01 00:01:40  49.598  15.009
# 2014-01-01 00:02:00  49.518  15.013
# 2014-01-01 00:03:20  49.200  15.059
# 2014-01-01 00:04:00  49.042  15.109

# %% [markdown]
# #### Other tips

# %%
# %%latex
# $$a = \int_a^b f(\alpha) d \alpha$$
# Out:
# $$a = \int_a^b f(\alpha) d \alpha$$

# %%
import JSAnimation
from JSAnimation import IPython_display
from matplotlib import animation

# create a simple animation
fig = plt.figure()
ax = plt.axes(xlim=(0, 10), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

x = np.linspace(0, 10, 1000)

def init():
    line.set_data([], [])
    return line,

def animate(i):
    line.set_data(x, np.cos(i * 0.02 * np.pi) * np.sin(x - i * 0.02 * np.pi))
    return line,

animation.FuncAnimation(fig, animate, init_func=init, 
                        frames=100, interval=20, blit=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-124-f77b38da1667> in <module>()
# ----> 1 import JSAnimation
#       2 from JSAnimation import IPython_display
#       3 from matplotlib import animation
#       4
#       5 # create a simple animation
#
# ImportError: No module named 'JSAnimation'
